# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open Paddington
img = Image.open("./Images/imagen.jpg")

# Resize smoothly down to 16x16 pixels
imgSmall = img.resize((20,20),resample=Image.BILINEAR)

# Scale back up using NEAREST to original size
result = imgSmall.resize(img.size,Image.NEAREST)
# Out:
# /tmp/uv0755/ipykernel_26816/1608534428.py:8: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   imgSmall = img.resize((20,20),resample=Image.BILINEAR)
# /tmp/uv0755/ipykernel_26816/1608534428.py:11: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   result = imgSmall.resize(img.size,Image.NEAREST)

# %%
plt.imshow(result)
plt.axis("off")
# Out:
# (-0.5, 239.5, 239.5, -0.5)

# %%
result.save('Madeline4.png')
